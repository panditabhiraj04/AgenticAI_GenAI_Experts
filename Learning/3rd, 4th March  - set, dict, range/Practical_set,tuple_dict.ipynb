# %%
mytuple = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mytuple
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
for i in enumerate(mytuple): 
    print(i) 

print(type(i))
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')
# <class 'tuple'>

# %%
myset3 = {10,20, "Hola", (11, 22, 32)} # Mixed datatypes 
myset3
# Out:
# {(11, 22, 32), 10, 20, 'Hola'}

# %%
myset4 = {10,20, "Hola", (11, 22, 32)} # set doesn't allow mutable items like li 
myset3 
myset4
# Out:
# {(11, 22, 32), 10, 20, 'Hola'}

# %%
myset5 = {1,2,4,[20,30]}
myset5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 myset5 = {1,2,4,[20,30]}
#       2 myset5
#
# TypeError: unhashable type: 'list'

# %%
myset6 = {[1,2,3]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 myset6 = {[1,2,3]}
#
# TypeError: unhashable type: 'list'

# %%
myset4.add(30)
myset4
# Out:
# {(11, 22, 32), 10, 20, 30, 'Hola'}

# %%
myset4.remove('NINE') # remove item in a set using remove() method 
myset4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 myset4.remove('NINE') # remove item in a set using remove() method
#       2 myset4
#
# KeyError: 'NINE'

# %%
myset5 = myset4.copy()
myset6 = myset4 # Create a new reference "myset1"  
myset5
# Out:
# {(11, 22, 32), 10, 20, 30, 'Hola'}

# %%
print(id(myset4))
print(id(myset5))
print(id(myset6))
# Out:
# 3152922464032
# 3152922468512
# 3152922464032

# %%
myset6.add('nine')
print(myset6)
print(myset4)
# Out:
# {'Hola', 10, 20, 'nine', (11, 22, 32), 30}
# {'Hola', 10, 20, 'nine', (11, 22, 32), 30}

# %%
mydict = {1:'one' , 2:'two' , 3:'three',1:'four'} # dictionary with integer keys 
mydict
# Out:
# {1: 'four', 2: 'two', 3: 'three'}

# %%
print(type(mydict.items()))
# Out:
# <class 'dict_items'>

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
mydict3 = dict.fromkeys(keys) # Create a dictionary from a sequence of keys 
mydict3
# Out:
# {'b': None, 'a': None, 'c': None, 'd': None}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
value = 10 
mydict3 = dict.fromkeys(keys , value) # Create a dictionary from a sequence of 
mydict3
# Out:
# {'b': 10, 'a': 10, 'c': 10, 'd': 10}
