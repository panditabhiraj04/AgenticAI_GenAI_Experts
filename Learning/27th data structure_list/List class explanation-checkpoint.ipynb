# %% [markdown]
# # LIST

# %%
l = [] 
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 9

# %%
l.append(10) 
l
# Out:
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]

# %%
l1 = [] 
l1
# Out:
# []

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]

# %%
l == l1
# Out:
# True

# %%
print(id(l))
print(id(l1))
# Out:
# 2325037215424
# 2325083094016

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]

# %%
l2 = []
l2
# Out:
# []

# %%
l2.append(2)
l2.append(2.3)
l2.append(True)
l2.append(1+2j)
l2.append('nit')
l2.append([1,2,3])

# %%
l2 #nested list
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
print(l)
print(l1) 
print(l2)
# Out:
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]

# %%
l.clear()

# %%
l
# Out:
# []

# %%
del l

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]

# %%
l1.count(20)
# Out:
# 2

# %%
l1.count(10)
# Out:
# 2

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.extend(l2)

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.index(200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 l1.index(200)
#
# ValueError: 200 is not in list

# %%
l2.index([1,2,3])
# Out:
# 5

# %%
l2.index(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 l2.index(0)
#
# ValueError: 0 is not in list

# %%
l2
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
for i in l2:
    print(i)
# Out:
# 2
# 2.3
# True
# (1+2j)
# nit
# [1, 2, 3]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 20, 30, 40, 50, 10]

# %%
l1.insert(1, 15)

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 20, 30, 40, 50, 10]

# %%
sal = [5000, 5000, 10000, ]
sal
# Out:
# [5000, 5000, 10000]

# %%
sal[2]
# Out:
# 10000

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 20, 30, 40, 50, 10]

# %%
l1.insert(3, 23)
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 20, 30, 40, 50, 10]

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 20, 30, 40, 50, 10]

# %%
l1.pop()
# Out:
# 10

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 20, 30, 40, 50]

# %%
l1.pop(3)
# Out:
# 23

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit']

# %%
l1.pop(20)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 l1.pop(20)
#
# IndexError: pop index out of range

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 20, 30, 40, 50]

# %%
l1.remove(200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 l1.remove(200)
#
# ValueError: list.remove(x): x not in list

# %%
l1.remove((1+2j))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 l1.remove((1+2j))
#
# ValueError: list.remove(x): x not in list

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 20, 30, 40, 50]

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 20, 30, 40, 50]
