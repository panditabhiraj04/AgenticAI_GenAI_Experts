# %% [markdown]
# # LIST

# %%
l = [] 
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(10)   # added value at end 
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1 = [] 
l1
# Out:
# []

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l == l1
# Out:
# True

# %%
print(id(l))
print(id(l1))
# Out:
# 2199914687168
# 2199914631936

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 20, 30, 40, 50, 10]

# %%
l2 = []
l2
# Out:
# []

# %%
l2.append(2)
l2.append(2.3)
l2.append(True)
l2.append(1+2j)
l2.append('nit')
l2.append([1,2,3])

# %%
l2 #nested list
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
print(l)
print(l1) 
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 20, 30, 40, 50, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l.clear()

# %%
l
# Out:
# []

# %%
del l

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1.count(20)
# Out:
# 1

# %%
l1.count(10)
# Out:
# 2

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.extend(l2)

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.index(200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 l1.index(200)
#
# ValueError: 200 is not in list

# %%
l2.index([1,2,3])
# Out:
# 5

# %%
l2
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
for i in l2:
    print(i)
# Out:
# 2
# 2.3
# True
# (1+2j)
# nit
# [1, 2, 3]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.insert(1, 15)

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
sal = [5000, 5000, 10000, ]
sal
# Out:
# [5000, 5000, 10000]

# %%
sal[2]
# Out:
# 10000

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.insert(3, 23)
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.pop()
# Out:
# [1, 2, 3]

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.pop(3)
# Out:
# 23

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.pop(20)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 l1.pop(20)
#
# IndexError: pop index out of range

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.remove(200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 l1.remove(200)
#
# ValueError: list.remove(x): x not in list

# %%
l1.remove((1+2j))

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1[:]
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
len(l1)
# Out:
# 13

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1[2:]
# Out:
# [20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1[:2]
# Out:
# [10, 15]

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1[::2]
# Out:
# [10, 20, 30, 50, 2, True, [1, 2, 3]]

# %%
l1[::3]
# Out:
# [10, 23, 50, 2.3, [1, 2, 3]]

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1[2:10:4]
# Out:
# [20, 50]

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1[::-1]
# Out:
# [[1, 2, 3], 'nit', True, 2.3, 2, 10, 50, 40, 30, 23, 20, 15, 10]

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1[::-2]
# Out:
# [[1, 2, 3], True, 2, 50, 30, 20, 10]

# %%
l1[-10:0:-2]
# Out:
# [23, 15]

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1[::-5]
# Out:
# [[1, 2, 3], 10, 20]

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l2 = ['a', 'b','c']

# %%
l2
# Out:
# ['a', 'b', 'c']

# %%
l2[-4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 l2[-4]
#
# IndexError: list index out of range

# %%
l2[-4:]
# Out:
# ['a', 'b', 'c']

# %%
l2
# Out:
# ['a', 'b', 'c']

# %%
l2[0]
# Out:
# 'a'

# %%
l2[0] = 'nit'

# %%
l2
# Out:
# ['nit', 'b', 'c']

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1[4] = 400

# %%
l1
# Out:
# [10, 15, 20, 23, 400, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1
# Out:
# [10, 15, 20, 23, 400, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1.index('nit')
# Out:
# 11

# %%
l1
# Out:
# [10, 15, 20, 23, 400, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1[10]
# Out:
# True

# %%
# nested indexing ( index inside index)

print(l1[10][0])
print(l1[10][1])
print(l1[10][2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 3
#       1 # nested indexing ( index inside index)
# ----> 3 print(l1[10][0])
#       4 print(l1[10][1])
#       5 print(l1[10][2])
#
# TypeError: 'bool' object is not subscriptable

# %%
l1
# Out:
# [10, 15, 20, 23, 400, 40, 50, 10, 2, 2.3, True, 'nit', [1, 2, 3]]

# %%
l1.reverse()

# %%
l1
# Out:
# [[1, 2, 3], 'nit', True, 2.3, 2, 10, 50, 40, 400, 23, 20, 15, 10]

# %%
l1
# Out:
# [[1, 2, 3], 'nit', True, 2.3, 2, 10, 50, 40, 400, 23, 20, 15, 10]

# %%
l2
# Out:
# ['nit', 'b', 'c']

# %%
l2.sort()

# %%
l2
# Out:
# ['b', 'c', 'nit']

# %%
l2.sort(reverse=True)
l2
# Out:
# ['nit', 'c', 'b']

# %%
l1
# Out:
# [[1, 2, 3], 'nit', True, 2.3, 2, 10, 50, 40, 400, 23, 20, 15, 10]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'list'

# %%
l1
# Out:
# [[1, 2, 3], 'nit', True, 2.3, 2, 10, 50, 40, 400, 23, 20, 15, 10]

# %%
l2
# Out:
# ['nit', 'c', 'b']

# %%
for i in l2:
    print(i)
# Out:
# nit
# c
# b

# %%
for i in enumerate(l2): # paired items 
    print(i)
# Out:
# (0, 'nit')
# (1, 'c')
# (2, 'b')

# %% [markdown]
# # List is completed

# %% [markdown]
# # TUPLE

# %%
t = ()
t
# Out:
# ()

# %%
t1 = (10, 20, 30, 40, 50, 50) 
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t2 = (10, 'prakash', 1+2j, True, 2.3)
t2
# Out:
# (10, 'prakash', (1+2j), True, 2.3)

# %%
print(t1)
print(t2)
# Out:
# (10, 20, 30, 40, 50, 50)
# (10, 'prakash', (1+2j), True, 2.3)

# %%
print(type(l1))
print(type(t1))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1.count(50)
# Out:
# 2

# %%
t1.index(10)
# Out:
# 0

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1[::-1]
# Out:
# (50, 50, 40, 30, 20, 10)

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1[5]
# Out:
# 50

# %%
t1[5] = 60 
t1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 t1[5] = 60
#       2 t1
#
# TypeError: 'tuple' object does not support item assignment

# %%
icici = (123, 'cizps43443')
icici
# Out:
# (123, 'cizps43443')

# %%
icici[0] = 456
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 icici[0] = 456
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1 * 3
# Out:
# (10, 20, 30, 40, 50, 50, 10, 20, 30, 40, 50, 50, 10, 20, 30, 40, 50, 50)

# %% [markdown]
# # TUPLE WE ARE COMPLETED

# %% [markdown]
# # SET

# %%
s = {} 
s
# Out:
# {}

# %%
type(s)
# Out:
# dict

# %%
s = set()
s
# Out:
# set()

# %%
type(s)
# Out:
# set

# %%
s = {1,2,3,4}

# %%
print(type(s))
# Out:
# <class 'set'>
