# %% [markdown]
# Day8
# - Python Data Type :
# - Int  - value without decimal
# - Float - value with decimal but in float only e letter is allowed, e/E(both allowed) - exponentional
# - Boolean(Bool) - True/False/None  - True - 1, False- 0 , None - no output for none
# - complex  - a+bj , a- real, b - imaginary part , j = squar root of -1 ,output comes under () -  parentheses are used to group the real and imaginary parts together,indicating that they form a single complex number.
#
# - String - declare without any value it will be a string.if we declare a value it will be a variable.
#           - pythone string must assinged ''|""|''' '''  -- from all the quotes we will get the output
#           - if user have single line use '' or ""
#           - if user have multiple line then please use  ''' '''
#
#
# - Inbuild functions: id(),type()
# - Inbuild function we called as parameter tunning
# - user define function called as hyper parameter tunning
# - 10/2 -output 5.0 # float division
# - 10//2 - out 5 # called int division
# - False/True - out 0.0 , False //True - out 0
# - True/False - out -ZeroDivisionError
# - Day by day text is incresing so llm model has born(large language model), What are those llm model
# - claude(antropic) -- MCP(Model Contenx protocol)
#   chtgpt(openai) by elonmask
#   gemni(google deepmind research company of google)
#   llama(facebook or meta)
#   deepseek(deepseek)
#   grok(xai)
#   kimi(moonshot ai)
#   qwen(alibaba)
#
# -

# %%
i = 4

# %%
j = 4.0

# %%
print(id(i))
print(id(j))
# Out:
# 140713176376328
# 1607490894768

# %%
type(i)
# Out:
# int

# %%
i = 2e0
i
# Out:
# 2.0

# %%
type(i)
# Out:
# float

# %%
j = 3E2
j
# Out:
# 300.0

# %%
True/False  #ZeroDivisionError
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
None
