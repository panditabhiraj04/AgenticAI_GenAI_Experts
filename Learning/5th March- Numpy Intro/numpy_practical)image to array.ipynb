# %%
import numpy as np

# %%
import matplotlib.pyplot as plt # matplotlib is the library for visulation

# %%
from PIL import Image # Pil image library --pyhton image library

# %%
horse = Image.open(r'C:\Users\pandi\Downloads\horse.jpeg')

# %%
horse
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x474>

# %%
type(horse)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
horse_arr = np.array(horse)   # convert image to array
horse_arr
# Out:
# array([[[111, 132, 137],
#         [101, 122, 127],
#         [ 96, 117, 122],
#         ...,
#         [ 30,  59,  77],
#         [ 33,  62,  80],
#         [ 33,  62,  80]],
#
#        [[107, 128, 133],
#         [106, 127, 132],
#         [104, 125, 130],
#         ...,
#         [ 30,  59,  77],
#         [ 32,  61,  79],
#         [ 32,  61,  79]],
#
#        [[143, 164, 169],
#         [142, 163, 168],
#         [129, 150, 155],
#         ...,
#         [ 30,  59,  77],
#         [ 31,  60,  78],
#         [ 31,  60,  78]],
#
#        ...,
#
#        [[ 78,  55,  23],
#         [ 77,  54,  22],
#         [ 81,  56,  25],
#         ...,
#         [159, 136, 105],
#         [158, 135, 104],
#         [158, 135, 104]],
#
#        [[ 96,  73,  42],
#         [ 66,  43,  12],
#         [ 74,  51,  20],
#         ...,
#         [166, 142, 114],
#         [166, 142, 114],
#         [163, 139, 111]],
#
#        [[ 96,  72,  44],
#         [ 66,  42,  14],
#         [ 74,  51,  20],
# ...

# %%
plt.imshow(horse_arr)   #  matplot library convert the image to gride section.

# %%
horse_arr.shape
# Out:
# (474, 474, 3)
