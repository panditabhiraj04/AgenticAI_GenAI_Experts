# %%
z = '#'

for i in range(1,5):
    for j in range(0,i):
        print(z,end = ' ')
    print()
# Out:
# #
# # #
# # # #
# # # # #

# %%
for i in range(5):
    print('# '*i)
# Out:
# #
# # #
# # # #
# # # # #

# %%
for i in range(1,5):
    print('# '*(5-i))
# Out:
# # # # #
# # # #
# # #
# #
