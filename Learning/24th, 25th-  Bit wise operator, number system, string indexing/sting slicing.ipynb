# %% [markdown]
# # python indexing & slicing

# %%
s1 = 'welcometeam'
s1
# Out:
# 'welcometeam'

# %%
type(s1)
# Out:
# str

# %%
len(s1)
# Out:
# 11

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[1] # forward index
# Out:
# 'e'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[-1]
# Out:
# 'm'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[:]
# Out:
# 'welcometeam'

# %%
s1[7:11]
# Out:
# 'team'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[7:]
# Out:
# 'team'

# %%
s1[:]
# Out:
# 'welcometeam'

# %%
s1[2:10]
# Out:
# 'lcometea'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[:10]
# Out:
# 'welcometea'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[4:]
# Out:
# 'ometeam'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[12:]
# Out:
# ''

# %%
s1[13]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 s1[13]
#
# IndexError: string index out of range

# %%
s1[:13]
# Out:
# 'welcometeam'

# %% [raw]
# -s1[left:right]
# -s1[left:right:step]

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[:15]
# Out:
# 'welcometeam'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[1:8:2]
# Out:
# 'ecmt'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[::3]
# Out:
# 'wcea'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[-9:-1:3]
# Out:
# 'lme'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[::-1]
# Out:
# 'maetemoclew'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[::-2]
# Out:
# 'meeolw'

# %% [markdown]
# # string we are compeleted
