# %%
#Binary number
print(bin(2))
print(bin(15))
print(oct(3))
print(oct(15))

print(hex(0))
print(hex(1))
print(hex(2))
print(hex(3))
print(hex(9))
print(hex(10))
print(hex(15))
print(hex(16))
print(hex(100))
print(hex(1000))

print(int(0b10)) 
print(int(0x0))
print(int(0x10))
# Out:
# 0b10
# 0b1111
# 0o3
# 0o17
# 0x0
# 0x1
# 0x2
# 0x3
# 0x9
# 0xa
# 0xf
# 0x10
# 0x64
# 0x3e8
# 2
# 0
# 16

# %%
print(~11)
print(~-11)
a=-25
print(~a)
# Out:
# -12
# 10
# 24

# %% [markdown]
# 12&13

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
12^13
# Out:
# 1

# %%
15^16
# Out:
# 31

# %%
12<<1
# Out:
# 24

# %%
12>>1
# Out:
# 6

# %%
12>>2
# Out:
# 3

# %%
print(bin(23))
23>>2  # output 5
# Out:
# 0b10111
# 5

# %%
import operator

print(operator.and_)
# Out:
# <built-in function and_>
