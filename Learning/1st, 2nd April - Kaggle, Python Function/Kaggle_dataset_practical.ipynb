# %%
import pandas as pd

# %%
movie =pd.read_csv(r'C:\Users\pandi\Desktop\Abhiraj\Data Science\Notes\Learning\1st, 2nd April - Kaggle, Python Function\movie.csv')

# %%
movie
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
tag =pd.read_csv(r'C:\Users\pandi\Desktop\Abhiraj\Data Science\Notes\Learning\1st, 2nd April - Kaggle, Python Function\tag.csv')

# %%
tag
# Out:
#         userId  movieId            tag            timestamp
# 0           18     4141    Mark Waters  2009-04-24 18:19:40
# 1           65      208      dark hero  2013-05-10 01:41:18
# 2           65      353      dark hero  2013-05-10 01:41:19
# 3           65      521  noir thriller  2013-05-10 01:39:43
# 4           65      592      dark hero  2013-05-10 01:41:18
# ...        ...      ...            ...                  ...
# 465559  138446    55999        dragged  2013-01-23 23:29:32
# 465560  138446    55999  Jason Bateman  2013-01-23 23:29:38
# 465561  138446    55999         quirky  2013-01-23 23:29:38
# 465562  138446    55999            sad  2013-01-23 23:29:32
# 465563  138472      923  rise to power  2007-11-02 21:12:47
#
# [465564 rows x 4 columns]

# %%
rating = pd.read_csv(r'C:\Users\pandi\Desktop\Abhiraj\Data Science\Notes\Learning\1st, 2nd April - Kaggle, Python Function\rating.csv',sep=',')

# %%
rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
del rating['timestamp']
del tag['timestamp']

# %%
tag_0 = tag.iloc[0]

# %%
tag.iloc[0]
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
type(tag_0)
# Out:
# pandas.core.series.Series

# %%
tag_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tag_0['userId']
# Out:
# np.int64(18)

# %%
'userId' in tag_0
# Out:
# True

# %%
tag_0.name
# Out:
# 0

# %%
tag_0.userId
# Out:
# np.int64(18)

# %%
tag_0['userId']
# Out:
# np.int64(18)

# %%
tag_0 = tag_0.rename('first_name')

# %%
tag_0.name
# Out:
# 'first_name'

# %%
tag.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tag.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tag.iloc[[0,1,2,3]]
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller

# %%
tag.iloc[:4]
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller

# %%
rating
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
rating.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
rating['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
rating.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
rating['rating'].max()
# Out:
# 5.0

# %%
rating['rating'].min()
# Out:
# 0.5

# %%
rating['rating'].std()
# Out:
# 1.051988919275684

# %%
rating['rating'].mode()
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
rating.corr()   #correlation b/w columns
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter1 = rating.rating > 10

# %%
filter1.any()
# Out:
# np.False_

# %%
filter2 = rating.rating>0

# %%
filter2.all()
# Out:
# np.True_

# %%
movie.shape
# Out:
# (27278, 3)

# %%
movie.isnull().any().any()   #representing no null value
# Out:
# np.False_

# %%
tag.isnull().any().any()  #tag have some null value
# Out:
# np.True_

# %%
rating.isnull().any().any()
# Out:
# np.False_

# %%
tag.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
#tag['tag'] = 'none'

# %%
tag['tag'].isnull().sum()
# Out:
# np.int64(16)

# %%
tag = tag.dropna()

# %%
tag.isnull().any().any()
# Out:
# np.False_

# %%
tag.shape     # drop the na records
# Out:
# (465548, 3)

# %%
rating
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
rating.hist(column = 'rating', figsize = (5,3))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
rating.boxplot(column= 'rating', figsize = (5,3))
# Out:
# <Axes: >

# %%
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie[1:20]
# Out:
#     movieId                                  title  \
# 1         2                         Jumanji (1995)
# 2         3                Grumpier Old Men (1995)
# 3         4               Waiting to Exhale (1995)
# 4         5     Father of the Bride Part II (1995)
# 5         6                            Heat (1995)
# 6         7                         Sabrina (1995)
# 7         8                    Tom and Huck (1995)
# 8         9                    Sudden Death (1995)
# 9        10                       GoldenEye (1995)
# 10       11         American President, The (1995)
# 11       12     Dracula: Dead and Loving It (1995)
# 12       13                           Balto (1995)
# 13       14                           Nixon (1995)
# 14       15                Cutthroat Island (1995)
# 15       16                          Casino (1995)
# 16       17           Sense and Sensibility (1995)
# 17       18                      Four Rooms (1995)
# ...

# %%
tag_count = tag['tag'].value_counts()
tag_count[-10:]
# Out:
# tag
# missing child                    1
# Ron Moore                        1
# Citizen Kane                     1
# mullet                           1
# biker gang                       1
# Paul Adelstein                   1
# the wig                          1
# killer fish                      1
# genetically modified monsters    1
# topless scene                    1
# Name: count, dtype: int64

# %%
tag['tag'].value_counts()
# Out:
# tag
# sci-fi                           3384
# based on a book                  3281
# atmospheric                      2917
# comedy                           2779
# action                           2657
#                                  ...
# Paul Adelstein                      1
# the wig                             1
# killer fish                         1
# genetically modified monsters       1
# topless scene                       1
# Name: count, Length: 38643, dtype: int64

# %%
tag_count[:10].plot(kind = 'bar',figsize = (5,3))
# Out:
# <Axes: xlabel='tag'>

# %%
high_rating = rating.rating >= 5.0

# %%
rating[high_rating][10:20]
# Out:
#      userId  movieId  rating
# 185       2      589     5.0
# 188       2      924     5.0
# 190       2     1196     5.0
# 191       2     1210     5.0
# 192       2     1214     5.0
# 193       2     1249     5.0
# 194       2     1259     5.0
# 195       2     1270     5.0
# 196       2     1327     5.0
# 197       2     1356     5.0

# %%
movie_flt = movie['genres'].str.contains('Action')

# %%
movie[movie_flt]
# Out:
#        movieId                           title  \
# 5            6                     Heat (1995)
# 8            9             Sudden Death (1995)
# 9           10                GoldenEye (1995)
# 14          15         Cutthroat Island (1995)
# 19          20              Money Train (1995)
# ...        ...                             ...
# 27168   130842            Power/Rangers (2015)
# 27187   130984      Santo vs. las lobas (1976)
# 27198   131025         The Brass Legend (1956)
# 27236   131122            Love Exposure (2007)
# 27264   131180  Dead Rising: Watchtower (2015)
#
#                                    genres
# 5                   Action|Crime|Thriller
# 8                                  Action
# 9               Action|Adventure|Thriller
# 14               Action|Adventure|Romance
# 19     Action|Comedy|Crime|Drama|Thriller
# ...                                   ...
# 27168             Action|Adventure|Sci-Fi
# 27187               Action|Fantasy|Horror
# ...

# %%
 rating[['movieId','rating']].groupby('rating').count()
# Out:
#         movieId
# rating
# 0.5      239125
# 1.0      680732
# 1.5      279252
# 2.0     1430997
# 2.5      883398
# 3.0     4291193
# 3.5     2200156
# 4.0     5561926
# 4.5     1534824
# 5.0     2898660

# %%
rating[['movieId', 'rating']].groupby('rating').mean()
# Out:
#              movieId
# rating
# 0.5     13356.246729
# 1.0      5652.208219
# 1.5     12377.773230
# 2.0      6733.595232
# 2.5     13669.268192
# 3.0      6770.763264
# 3.5     14814.098703
# 4.0      8342.514461
# 4.5     14585.414824
# 5.0      6275.356017

# %%
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tag.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
t1 = movie.merge(tag, on ='movieId', how = 'inner')

# %%
t1.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId                                     tag
# 0    1644                                 Watched
# 1    1741                      computer animation
# 2    1741                 Disney animated feature
# 3    1741                         Pixar animation
# 4    1741  TÃ©a Leoni does not star in this movie

# %%
avg_rating = rating[['movieId','rating']].groupby('movieId').mean()

# %%
avg_rating.head
# Out:
# <bound method NDFrame.head of            rating
# movieId
# 1        3.921240
# 2        3.211977
# 3        3.151040
# 4        2.861393
# 5        3.064592
# ...           ...
# 131254   4.000000
# 131256   4.000000
# 131258   2.500000
# 131260   3.000000
# 131262   4.000000
#
# [26744 rows x 1 columns]>
