# %%
# not clear fully 

result = 5 + 3 * 2 / 2 - (4 % 3) ** 2

print(result)
# Out:
# 7.0

# %%
#bitwise logic not clear
# Out:
# 1

# %%
#Membership operator - in | not in  - it is used for find the value is present or not in the sequence 
a = ['c',10,'d']

result = 10 in a
result2 = 'car' not in a
result3 = 'd' not in a
print(result)
print(result2)
print(result3)
# Out:
# True
# True
# False

# %%
# identity operatior = is | is not - it is used to test the identity, two variable refer the same memorary location or not 

a = 10
b= 15

re= a is b
re2= a is not b
re3= a is  a

print(re)
print(re2)
print(re3)
# Out:
# False
# True
# True

# %%
#ternary operator - it is the shortest way to right the if and else exprestion
t = 50
result = 'sunny' if t >30 else cloudy
print(result)
# Out:
# sunny

# %%
A = 'at'
B = 'aw'

print(A<B)
# Out:
# True
