# %% [markdown]
# Type casting
# -Bool
# non zero argument is alwase true
# all other datatype to bool possible
#
# -String
# all other datatype to string possible

# %%
bool( ) # space bool is False

# %%
bool(@)  # errror SyntaxError
# Out:
#   Cell In[1], line 1
#     bool(@)
#          ^
# SyntaxError: invalid syntax

# %%
bool(10)
# Out:
# True

# %%
bool(0) # flase
# Out:
# False

# %%
bool(0.1)   # true
# Out:
# True

# %%
bool(1+2j) # true

# %%
bool(2+) # error

# %%
bool('10') # true
# Out:
# True

# %%
bool('ten') # true

# %%
bool('') # false
# Out:
# False

# %%
bool('zero')
# Out:
# True

# %% [markdown]
# Other data type to string

# %%
str(1)  #'1'
# Out:
# '1'

# %%
str(2.5)  # '2.5'

# %%
str(True) #'True'

# %%
str(true)  # NameError:
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 str(true)
#
# NameError: name 'true' is not defined

# %%
str(1+2j) #'(1+2j)'
# Out:
# '(1+2j)'

# %%
str(False)
# Out:
# 'False'
