# %% [markdown]
# Python operator :
#
# - Arithmetic  : +,-,*,/,//,%,**,
#   - [x1**y1] - squar
#   - [x1/x2] - desimal
#   - [x1//x2] 10//5-2
#   - [10%5] - remindar 0
# - Assingment : =,+=,-+,*=,/=,//=,%=
# - Relational : <,>,==,!=,>=,<=,
# - Logical : and , not , or
#    - 1 and 1 is 1 & rest of them are 0
#    - 0 or 0 is 0 & rest of them are 1
# - Unary - means only 1 operator/ it will give only negattion value
# - Bitwise

# %% [markdown]
# String indexing & Slicing :
#
# - index begins with 0 and ends with (n-1)
# - Forward indexing : >>>> left - right -- begins with 0
# - Backward indexing : <<<< right - left -- begains with -1
# -

# %%
s = 'welcome'
s
# Out:
# 'welcome'

# %%
s[5] # 'm'
# Out:
# 'm'

# %%
s[10] #IndexError: string index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s[10]
#
# IndexError: string index out of range

# %%
import ctypes
a = -10
print(id(a))
# Out:
# 2680688808048

# %%
a= ctypes.cast(a,ctypes.py_object)

print(a)
